# %%
# gym-maze-trustycoder83
import gym_maze
import gym
import numpy as np
import math
import random
import os

class Agent(object):
    def __init__(self):

        self.env = gym.make('maze-sample-5x5-v0')
        self.dim = 5
        self.os_n = self.dim * self.dim      # |S|
        self.as_n = self.env.action_space.n  # |A|

        self.c = 5
        # self.delta = .01
        self.delta = .1
        # self.epsilon = .01
        self.epsilon = .1
        self.discount_rate = .83
        self.learning_rate = 0.1
        self.difference_estimation = []

        initial_value = math.log(1. * self.c * self.os_n * self.as_n / self.delta)
        self.Q_up = np.zeros((self.dim, self.dim, self.as_n)) + initial_value
        self.Q_down = np.zeros((self.dim, self.dim, self.as_n)) - initial_value
        self.n = np.ones([self.dim, self.dim, self.as_n])
        self.U = [list([[k for k in range (self.as_n)] for j in range(self.dim)]) for i in range(self.dim)]
        self.iteration = 0
        self.t_max = 300


    def model_free_action_elimination(self):
        s1, s2 = self.reset()
        while True:
            
            for i in range(self.t_max):
                self.U[s1][s2] = list()

                # obtain U-set
                for a in range(self.as_n):
                    
                    if self.Q_up[s1][s2][a] >= np.max(self.Q_down[s1][s2]):
                        self.U[s1][s2].append(a)

                a = random.sample(self.U[s1][s2], 1)[0]
                s1_next, s2_next, r, done, _ = self.step(a)

                # count(选中次数)
                n = float(self.n[s1][s2][a])
                # print(self.Q_up[s][a], self.Q_down[s][a])
                    
                # Update.
                self.Q_up[s1][s2][a] = (1. - self.learning_rate) * self.Q_up[s1][s2][a] + self.learning_rate * (r + self.discount_rate * np.max(self.Q_up[s1_next][s2_next]) + self.beta(n))
                self.Q_down[s1][s2][a] = (1. - self.learning_rate) * self.Q_down[s1][s2][a] + self.learning_rate * (r + self.discount_rate * np.max(self.Q_down[s1_next][s2_next]) - self.beta(n))
                self.n[s1][s2][a] += 1

                s1, s2 = s1_next, s2_next
                # print(self.Q_up[s][a], self.Q_down[s][a])

                if done or i == self.t_max-1:
                    print('iteration:%d' % self.iteration)
                    print('iteration done! step: %d reward: %d, state: %d %d' % (i, r, s1, s2))
                    s1, s2 = self.reset()
                    break

            self.iteration += 1
            
            print('action set%s' %self.U[s1][s2])
            self.check_stopping_conditions()
            print('\n')

    def step(self, a):
        s, r, done, _ = self.env.step(a)
        # 将奖励大于0
        r = max(r, 0.)
        return s[0], s[1], r, done, _

    def reset(self):
        s = self.env.reset()
        return s[0], s[1]
                
    def check_stopping_conditions(self):
        for s1 in range(self.dim):
            for s2 in range(self.dim):
                for a in self.U[s1][s2]:
                    former = math.fabs(self.Q_up[s1][s2][a] - self.Q_down[s1][s2][a])
                    if former >= self.epsilon * (1-self.discount_rate) / 2.:
                        print('%f >= %f' % ((former, self.epsilon * (1-self.discount_rate) / 2)))
                        # print(np.absolute(self.Q_up - self.Q_down),np.mean(np.absolute(self.Q_up - self.Q_down)))
                        # exit()
                        self.difference_estimation.append(former)
                        return

        print('satified done')
        exit(0)
    
    
    def beta(self, k):
        return math.sqrt(math.log(1. * self.c * k * k * self.os_n * self.as_n / self.delta) / (1. * k))
    
    def animation(self, policy, count):
        for _ in range(count):
            self.run_episode(policy, True)
        self.env.close()
        
    def solution_policy(self,table):
        policy = np.argmax(table, axis=2)
        policy_scores = [self.run_episode(policy, False) for _ in range(10)]
        print("Return of solution = ", np.mean(policy_scores))
        return policy
    
    def run_episode(self, policy, render=False):
        obs = self.env.reset()
        total_reward = 0
        step_idx = 0
        for _ in range(self.t_max):
            if render:
                self.env.render()

            a,b = obs[0],obs[1]
            action = policy[a][b]
            action = int(action)
            obs, reward, done, _ = self.env.step(action)
            total_reward += self.discount_rate ** step_idx * reward
            step_idx += 1
            if done:
                break
        
        return total_reward

# %%
agent = Agent()
agent.model_free_action_elimination()
# Out:
# iteration:0
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 15.385987 >= 0.008500
#
#
# iteration:1
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 14.213451 >= 0.008500
#
#
# iteration:2
# iteration done! step: 57 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 13.993814 >= 0.008500
#
#
# iteration:3
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 12.593879 >= 0.008500
#
#
# iteration:4
# iteration done! step: 299 reward: 0, state: 1 4
# action set[0, 1, 2, 3]
# 11.292354 >= 0.008500
#
#
# iteration:5
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 10.719478 >= 0.008500
#
#
# iteration:6
# iteration done! step: 299 reward: 0, state: 3 4
# action set[0, 1, 2, 3]
# 9.761528 >= 0.008500
#
#
# iteration:7
# iteration done! step: 219 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 9.712061 >= 0.008500
#
#
# iteration:8
# iteration done! step: 197 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 9.658980 >= 0.008500
#
#
# iteration:9
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 8.784677 >= 0.008500
#
#
# iteration:10
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 8.482594 >= 0.008500
#
#
# iteration:11
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 8.170721 >= 0.008500
#
#
# iteration:12
# iteration done! step: 299 reward: 0, state: 0 1
# action set[0, 1, 2, 3]
# 8.088271 >= 0.008500
#
#
# iteration:13
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 7.305738 >= 0.008500
#
#
# iteration:14
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 7.028709 >= 0.008500
#
#
# iteration:15
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 6.560877 >= 0.008500
#
#
# iteration:16
# iteration done! step: 299 reward: 0, state: 0 1
# action set[0, 1, 2, 3]
# 6.507159 >= 0.008500
#
#
# iteration:17
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 6.209424 >= 0.008500
#
#
# iteration:18
# iteration done! step: 292 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 6.186407 >= 0.008500
#
#
# iteration:19
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 6.186407 >= 0.008500
#
#
# iteration:20
# iteration done! step: 299 reward: 0, state: 1 3
# action set[0, 1, 2, 3]
# 6.042846 >= 0.008500
#
#
# iteration:21
# iteration done! step: 271 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 5.867697 >= 0.008500
#
#
# iteration:22
# iteration done! step: 299 reward: 0, state: 0 3
# action set[0, 1, 2, 3]
# 5.825454 >= 0.008500
#
#
# iteration:23
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 5.720880 >= 0.008500
#
#
# iteration:24
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 5.678637 >= 0.008500
#
#
# iteration:25
# iteration done! step: 291 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 5.402260 >= 0.008500
#
#
# iteration:26
# iteration done! step: 299 reward: 0, state: 2 3
# action set[0, 1, 2, 3]
# 5.313073 >= 0.008500
#
#
# iteration:27
# iteration done! step: 299 reward: 0, state: 0 4
# action set[0, 1, 2, 3]
# 5.051660 >= 0.008500
#
#
# iteration:28
# iteration done! step: 299 reward: 0, state: 2 3
# action set[0, 1, 2, 3]
# 4.960278 >= 0.008500
#
#
# iteration:29
# iteration done! step: 299 reward: 0, state: 2 3
# action set[0, 1, 2, 3]
# 4.887167 >= 0.008500
#
#
# iteration:30
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 4.773855 >= 0.008500
#
#
# iteration:31
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 4.640386 >= 0.008500
#
#
# iteration:32
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 4.528836 >= 0.008500
#
#
# iteration:33
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 4.396830 >= 0.008500
#
#
# iteration:34
# iteration done! step: 142 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 4.353789 >= 0.008500
#
#
# iteration:35
# iteration done! step: 299 reward: 0, state: 0 1
# action set[0, 1, 2, 3]
# 4.333705 >= 0.008500
#
#
# iteration:36
# iteration done! step: 280 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 4.301459 >= 0.008500
#
#
# iteration:37
# iteration done! step: 135 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 4.239895 >= 0.008500
#
#
# iteration:38
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 3.960877 >= 0.008500
#
#
# iteration:39
# iteration done! step: 151 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.943302 >= 0.008500
#
#
# iteration:40
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 3.931252 >= 0.008500
#
#
# iteration:41
# iteration done! step: 253 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.891804 >= 0.008500
#
#
# iteration:42
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 3.872819 >= 0.008500
#
#
# iteration:43
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 3.853867 >= 0.008500
#
#
# iteration:44
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 3.840516 >= 0.008500
#
#
# iteration:45
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 3.799498 >= 0.008500
#
#
# iteration:46
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 3.748851 >= 0.008500
#
#
# iteration:47
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 3.717138 >= 0.008500
#
#
# iteration:48
# iteration done! step: 299 reward: 0, state: 0 1
# action set[0, 1, 2, 3]
# 3.636576 >= 0.008500
#
#
# iteration:49
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 3.632351 >= 0.008500
#
#
# iteration:50
# iteration done! step: 285 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.632351 >= 0.008500
#
#
# iteration:51
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 3.604905 >= 0.008500
#
#
# iteration:52
# iteration done! step: 211 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.584236 >= 0.008500
#
#
# iteration:53
# iteration done! step: 286 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.550996 >= 0.008500
#
#
# iteration:54
# iteration done! step: 115 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.511106 >= 0.008500
#
#
# iteration:55
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 3.467221 >= 0.008500
#
#
# iteration:56
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 3.391737 >= 0.008500
#
#
# iteration:57
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 3.379632 >= 0.008500
#
#
# iteration:58
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 3.321180 >= 0.008500
#
#
# iteration:59
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 3.296011 >= 0.008500
#
#
# iteration:60
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 3.272753 >= 0.008500
#
#
# iteration:61
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 3.215408 >= 0.008500
#
#
# iteration:62
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 3.207698 >= 0.008500
#
#
# iteration:63
# iteration done! step: 296 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.203402 >= 0.008500
#
#
# iteration:64
# iteration done! step: 261 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.203402 >= 0.008500
#
#
# iteration:65
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 3.160385 >= 0.008500
#
#
# iteration:66
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 3.156656 >= 0.008500
#
#
# iteration:67
# iteration done! step: 155 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.151472 >= 0.008500
#
#
# iteration:68
# iteration done! step: 276 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.141536 >= 0.008500
#
#
# iteration:69
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 3.108123 >= 0.008500
#
#
# iteration:70
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 3.079118 >= 0.008500
#
#
# iteration:71
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 3.076382 >= 0.008500
#
#
# iteration:72
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 3.064513 >= 0.008500
#
#
# iteration:73
# iteration done! step: 172 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.060100 >= 0.008500
#
#
# iteration:74
# iteration done! step: 207 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 3.049112 >= 0.008500
#
#
# iteration:75
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 3.026535 >= 0.008500
#
#
# iteration:76
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 2.987423 >= 0.008500
#
#
# iteration:77
# iteration done! step: 299 reward: 0, state: 0 4
# action set[0, 1, 2, 3]
# 2.953689 >= 0.008500
#
#
# iteration:78
# iteration done! step: 250 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.943029 >= 0.008500
#
#
# iteration:79
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 2.897952 >= 0.008500
#
#
# iteration:80
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 2.895260 >= 0.008500
#
#
# iteration:81
# iteration done! step: 299 reward: 0, state: 2 3
# action set[0, 1, 2, 3]
# 2.886183 >= 0.008500
#
#
# iteration:82
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 2.868895 >= 0.008500
#
#
# iteration:83
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 2.838327 >= 0.008500
#
#
# iteration:84
# iteration done! step: 157 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.827758 >= 0.008500
#
#
# iteration:85
# iteration done! step: 88 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.819046 >= 0.008500
#
#
# iteration:86
# iteration done! step: 143 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.809932 >= 0.008500
#
#
# iteration:87
# iteration done! step: 30 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.809932 >= 0.008500
#
#
# iteration:88
# iteration done! step: 241 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.797318 >= 0.008500
# iteration:89
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 2.785337 >= 0.008500
#
#
# iteration:90
# iteration done! step: 109 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.780015 >= 0.008500
#
#
# iteration:91
# iteration done! step: 190 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.761519 >= 0.008500
#
#
# iteration:92
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 2.743807 >= 0.008500
#
#
# iteration:93
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 2.729486 >= 0.008500
#
#
# iteration:94
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 2.707940 >= 0.008500
#
#
# iteration:95
# iteration done! step: 192 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.704249 >= 0.008500
#
#
# iteration:96
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 2.675184 >= 0.008500
#
#
# iteration:97
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 2.675184 >= 0.008500
#
#
# iteration:98
# iteration done! step: 96 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.675184 >= 0.008500
#
#
# iteration:99
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 2.650281 >= 0.008500
#
#
# iteration:100
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 2.643172 >= 0.008500
#
#
# iteration:101
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 2.629651 >= 0.008500
#
#
# iteration:102
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 2.607700 >= 0.008500
#
#
# iteration:103
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 2.602768 >= 0.008500
#
#
# iteration:104
# iteration done! step: 126 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.594821 >= 0.008500
#
#
# iteration:105
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 2.588920 >= 0.008500
#
#
# iteration:106
# iteration done! step: 299 reward: 0, state: 3 4
# action set[0, 1, 2, 3]
# 2.572040 >= 0.008500
#
#
# iteration:107
# iteration done! step: 163 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.567935 >= 0.008500
#
#
# iteration:108
# iteration done! step: 246 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.553476 >= 0.008500
#
#
# iteration:109
# iteration done! step: 299 reward: 0, state: 3 3
# action set[0, 1, 2, 3]
# 2.546663 >= 0.008500
#
#
# iteration:110
# iteration done! step: 182 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.538460 >= 0.008500
#
#
# iteration:111
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 2.521928 >= 0.008500
#
#
# iteration:112
# iteration done! step: 183 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.516121 >= 0.008500
#
#
# iteration:113
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 2.500407 >= 0.008500
#
#
# iteration:114
# iteration done! step: 251 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.495319 >= 0.008500
#
#
# iteration:115
# iteration done! step: 299 reward: 0, state: 0 3
# action set[0, 1, 2, 3]
# 2.485816 >= 0.008500
#
#
# iteration:116
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 2.474579 >= 0.008500
#
#
# iteration:117
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 2.474579 >= 0.008500
#
#
# iteration:118
# iteration done! step: 299 reward: 0, state: 2 3
# action set[0, 1, 2, 3]
# 2.463041 >= 0.008500
#
#
# iteration:119
# iteration done! step: 275 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.455111 >= 0.008500
#
#
# iteration:120
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 2.437550 >= 0.008500
#
#
# iteration:121
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 2.418388 >= 0.008500
#
#
# iteration:122
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 2.397912 >= 0.008500
#
#
# iteration:123
# iteration done! step: 257 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.386682 >= 0.008500
#
#
# iteration:124
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 2.378043 >= 0.008500
#
#
# iteration:125
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 2.376968 >= 0.008500
#
#
# iteration:126
# iteration done! step: 92 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.373807 >= 0.008500
#
#
# iteration:127
# iteration done! step: 240 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.371670 >= 0.008500
#
#
# iteration:128
# iteration done! step: 211 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.364352 >= 0.008500
#
#
# iteration:129
# iteration done! step: 299 reward: 0, state: 2 4
# action set[0, 1, 2, 3]
# 2.354462 >= 0.008500
#
#
# iteration:130
# iteration done! step: 299 reward: 0, state: 2 4
# action set[0, 1, 2, 3]
# 2.346213 >= 0.008500
#
#
# iteration:131
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 2.343070 >= 0.008500
#
#
# iteration:132
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 2.321201 >= 0.008500
#
#
# iteration:133
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 2.299131 >= 0.008500
#
#
# iteration:134
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 2.294111 >= 0.008500
#
#
# iteration:135
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 2.289429 >= 0.008500
#
#
# iteration:136
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 2.286036 >= 0.008500
#
#
# iteration:137
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 2.272254 >= 0.008500
#
#
# iteration:138
# iteration done! step: 93 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.270126 >= 0.008500
#
#
# iteration:139
# iteration done! step: 179 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.270126 >= 0.008500
#
#
# iteration:140
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 2.256048 >= 0.008500
#
#
# iteration:141
# iteration done! step: 141 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.254090 >= 0.008500
#
#
# iteration:142
# iteration done! step: 299 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.254090 >= 0.008500
#
#
# iteration:143
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 2.248494 >= 0.008500
#
#
# iteration:144
# iteration done! step: 299 reward: 0, state: 0 4
# action set[0, 1, 2, 3]
# 2.239570 >= 0.008500
#
#
# iteration:145
# iteration done! step: 299 reward: 0, state: 1 3
# action set[0, 1, 2, 3]
# 2.238353 >= 0.008500
#
#
# iteration:146
# iteration done! step: 97 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.234515 >= 0.008500
#
#
# iteration:147
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 2.222000 >= 0.008500
#
#
# iteration:148
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 2.212880 >= 0.008500
#
#
# iteration:149
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 2.197904 >= 0.008500
#
#
# iteration:150
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 2.196418 >= 0.008500
#
#
# iteration:151
# iteration done! step: 163 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.195008 >= 0.008500
#
#
# iteration:152
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 2.185773 >= 0.008500
#
#
# iteration:153
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 2.178405 >= 0.008500
#
#
# iteration:154
# iteration done! step: 202 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.175758 >= 0.008500
#
#
# iteration:155
# iteration done! step: 191 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.174227 >= 0.008500
#
#
# iteration:156
# iteration done! step: 276 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.171561 >= 0.008500
#
#
# iteration:157
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 2.155897 >= 0.008500
#
#
# iteration:158
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 2.153125 >= 0.008500
#
#
# iteration:159
# iteration done! step: 243 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.153125 >= 0.008500
#
#
# iteration:160
# iteration done! step: 199 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.144757 >= 0.008500
#
#
# iteration:161
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 2.138988 >= 0.008500
#
#
# iteration:162
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 2.134535 >= 0.008500
#
#
# iteration:163
# iteration done! step: 129 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.133361 >= 0.008500
#
#
# iteration:164
# iteration done! step: 250 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.130033 >= 0.008500
#
#
# iteration:165
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 2.121620 >= 0.008500
#
#
# iteration:166
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 2.115895 >= 0.008500
#
#
# iteration:167
# iteration done! step: 84 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.115187 >= 0.008500
#
#
# iteration:168
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 2.111527 >= 0.008500
#
#
# iteration:169
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 2.106490 >= 0.008500
#
#
# iteration:170
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 2.098061 >= 0.008500
# iteration:171
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 2.087365 >= 0.008500
#
#
# iteration:172
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 2.084513 >= 0.008500
#
#
# iteration:173
# iteration done! step: 202 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.081096 >= 0.008500
#
#
# iteration:174
# iteration done! step: 64 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.080192 >= 0.008500
#
#
# iteration:175
# iteration done! step: 299 reward: 0, state: 2 3
# action set[0, 1, 2, 3]
# 2.072776 >= 0.008500
#
#
# iteration:176
# iteration done! step: 227 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.067605 >= 0.008500
#
#
# iteration:177
# iteration done! step: 299 reward: 0, state: 0 3
# action set[0, 1, 2, 3]
# 2.064438 >= 0.008500
#
#
# iteration:178
# iteration done! step: 286 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.061508 >= 0.008500
#
#
# iteration:179
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 2.058887 >= 0.008500
#
#
# iteration:180
# iteration done! step: 89 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.055094 >= 0.008500
#
#
# iteration:181
# iteration done! step: 191 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.053786 >= 0.008500
#
#
# iteration:182
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 2.053786 >= 0.008500
#
#
# iteration:183
# iteration done! step: 225 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.044974 >= 0.008500
#
#
# iteration:184
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 2.040717 >= 0.008500
#
#
# iteration:185
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 2.028688 >= 0.008500
#
#
# iteration:186
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 2.027477 >= 0.008500
#
#
# iteration:187
# iteration done! step: 193 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.026687 >= 0.008500
#
#
# iteration:188
# iteration done! step: 299 reward: 0, state: 0 3
# action set[0, 1, 2, 3]
# 2.026687 >= 0.008500
#
#
# iteration:189
# iteration done! step: 132 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.016194 >= 0.008500
#
#
# iteration:190
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 2.011269 >= 0.008500
#
#
# iteration:191
# iteration done! step: 287 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 2.008710 >= 0.008500
#
#
# iteration:192
# iteration done! step: 299 reward: 0, state: 0 4
# action set[0, 1, 2, 3]
# 2.005197 >= 0.008500
#
#
# iteration:193
# iteration done! step: 299 reward: 0, state: 0 1
# action set[0, 1, 2, 3]
# 1.998079 >= 0.008500
#
#
# iteration:194
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 1.991959 >= 0.008500
#
#
# iteration:195
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 1.983364 >= 0.008500
#
#
# iteration:196
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.977050 >= 0.008500
#
#
# iteration:197
# iteration done! step: 185 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.975819 >= 0.008500
#
#
# iteration:198
# iteration done! step: 231 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.973289 >= 0.008500
#
#
# iteration:199
# iteration done! step: 231 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.970369 >= 0.008500
#
#
# iteration:200
# iteration done! step: 86 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.969584 >= 0.008500
#
#
# iteration:201
# iteration done! step: 299 reward: 0, state: 0 3
# action set[0, 1, 2, 3]
# 1.965370 >= 0.008500
#
#
# iteration:202
# iteration done! step: 191 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.964964 >= 0.008500
#
#
# iteration:203
# iteration done! step: 140 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.964179 >= 0.008500
#
#
# iteration:204
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 1.954862 >= 0.008500
#
#
# iteration:205
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 1.949598 >= 0.008500
#
#
# iteration:206
# iteration done! step: 299 reward: 0, state: 2 4
# action set[0, 1, 2, 3]
# 1.949598 >= 0.008500
#
#
# iteration:207
# iteration done! step: 299 reward: 0, state: 0 3
# action set[0, 1, 2, 3]
# 1.948338 >= 0.008500
#
#
# iteration:208
# iteration done! step: 93 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.947904 >= 0.008500
#
#
# iteration:209
# iteration done! step: 154 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.946246 >= 0.008500
#
#
# iteration:210
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.943070 >= 0.008500
#
#
# iteration:211
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 1.929805 >= 0.008500
#
#
# iteration:212
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 1.927467 >= 0.008500
#
#
# iteration:213
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.927467 >= 0.008500
#
#
# iteration:214
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 1.923401 >= 0.008500
#
#
# iteration:215
# iteration done! step: 174 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.923401 >= 0.008500
#
#
# iteration:216
# iteration done! step: 207 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.919157 >= 0.008500
#
#
# iteration:217
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 1.907077 >= 0.008500
#
#
# iteration:218
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 1.903255 >= 0.008500
#
#
# iteration:219
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 1.891430 >= 0.008500
#
#
# iteration:220
# iteration done! step: 246 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.888205 >= 0.008500
#
#
# iteration:221
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 1.885436 >= 0.008500
#
#
# iteration:222
# iteration done! step: 299 reward: 0, state: 0 4
# action set[0, 1, 2, 3]
# 1.880923 >= 0.008500
#
#
# iteration:223
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 1.876274 >= 0.008500
#
#
# iteration:224
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 1.871837 >= 0.008500
#
#
# iteration:225
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 1.866240 >= 0.008500
#
#
# iteration:226
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 1.864080 >= 0.008500
#
#
# iteration:227
# iteration done! step: 248 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.862664 >= 0.008500
#
#
# iteration:228
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 1.856809 >= 0.008500
#
#
# iteration:229
# iteration done! step: 299 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.855593 >= 0.008500
#
#
# iteration:230
# iteration done! step: 126 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.854529 >= 0.008500
#
#
# iteration:231
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 1.848034 >= 0.008500
#
#
# iteration:232
# iteration done! step: 212 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.846880 >= 0.008500
#
#
# iteration:233
# iteration done! step: 299 reward: 0, state: 0 4
# action set[0, 1, 2, 3]
# 1.846607 >= 0.008500
#
#
# iteration:234
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.839029 >= 0.008500
#
#
# iteration:235
# iteration done! step: 299 reward: 0, state: 1 3
# action set[0, 1, 2, 3]
# 1.838344 >= 0.008500
#
#
# iteration:236
# iteration done! step: 186 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.837963 >= 0.008500
#
#
# iteration:237
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 1.835454 >= 0.008500
#
#
# iteration:238
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 1.831024 >= 0.008500
#
#
# iteration:239
# iteration done! step: 169 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.827989 >= 0.008500
#
#
# iteration:240
# iteration done! step: 299 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.826443 >= 0.008500
#
#
# iteration:241
# iteration done! step: 121 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.826443 >= 0.008500
#
#
# iteration:242
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 1.817296 >= 0.008500
#
#
# iteration:243
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 1.815960 >= 0.008500
#
#
# iteration:244
# iteration done! step: 147 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.815960 >= 0.008500
#
#
# iteration:245
# iteration done! step: 278 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.811008 >= 0.008500
#
#
# iteration:246
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 1.808009 >= 0.008500
#
#
# iteration:247
# iteration done! step: 265 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.803706 >= 0.008500
# iteration:248
# iteration done! step: 160 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.802424 >= 0.008500
#
#
# iteration:249
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.796469 >= 0.008500
#
#
# iteration:250
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 1.792378 >= 0.008500
#
#
# iteration:251
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 1.791414 >= 0.008500
#
#
# iteration:252
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 1.791414 >= 0.008500
#
#
# iteration:253
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 1.788160 >= 0.008500
#
#
# iteration:254
# iteration done! step: 222 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.785926 >= 0.008500
#
#
# iteration:255
# iteration done! step: 271 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.782139 >= 0.008500
#
#
# iteration:256
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 1.771729 >= 0.008500
#
#
# iteration:257
# iteration done! step: 299 reward: 0, state: 1 3
# action set[0, 1, 2, 3]
# 1.771396 >= 0.008500
#
#
# iteration:258
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 1.768684 >= 0.008500
#
#
# iteration:259
# iteration done! step: 299 reward: 0, state: 0 4
# action set[0, 1, 2, 3]
# 1.766115 >= 0.008500
#
#
# iteration:260
# iteration done! step: 299 reward: 0, state: 0 3
# action set[0, 1, 2, 3]
# 1.763775 >= 0.008500
#
#
# iteration:261
# iteration done! step: 299 reward: 0, state: 1 3
# action set[0, 1, 2, 3]
# 1.762379 >= 0.008500
#
#
# iteration:262
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 1.761381 >= 0.008500
#
#
# iteration:263
# iteration done! step: 214 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.757371 >= 0.008500
#
#
# iteration:264
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 1.754412 >= 0.008500
#
#
# iteration:265
# iteration done! step: 299 reward: 0, state: 2 3
# action set[0, 1, 2, 3]
# 1.753406 >= 0.008500
#
#
# iteration:266
# iteration done! step: 299 reward: 0, state: 2 3
# action set[0, 1, 2, 3]
# 1.750159 >= 0.008500
#
#
# iteration:267
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 1.750159 >= 0.008500
#
#
# iteration:268
# iteration done! step: 299 reward: 0, state: 0 3
# action set[0, 1, 2, 3]
# 1.749466 >= 0.008500
#
#
# iteration:269
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 1.747852 >= 0.008500
#
#
# iteration:270
# iteration done! step: 184 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.746293 >= 0.008500
#
#
# iteration:271
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 1.743415 >= 0.008500
#
#
# iteration:272
# iteration done! step: 289 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.743124 >= 0.008500
#
#
# iteration:273
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 1.741080 >= 0.008500
#
#
# iteration:274
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 1.733695 >= 0.008500
#
#
# iteration:275
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 1.730057 >= 0.008500
#
#
# iteration:276
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.729366 >= 0.008500
#
#
# iteration:277
# iteration done! step: 193 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.727401 >= 0.008500
#
#
# iteration:278
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.723179 >= 0.008500
#
#
# iteration:279
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.719869 >= 0.008500
#
#
# iteration:280
# iteration done! step: 299 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.717580 >= 0.008500
#
#
# iteration:281
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 1.717004 >= 0.008500
#
#
# iteration:282
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 1.715242 >= 0.008500
#
#
# iteration:283
# iteration done! step: 289 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.710355 >= 0.008500
#
#
# iteration:284
# iteration done! step: 293 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.709264 >= 0.008500
#
#
# iteration:285
# iteration done! step: 257 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.708209 >= 0.008500
#
#
# iteration:286
# iteration done! step: 299 reward: 0, state: 1 4
# action set[0, 1, 2, 3]
# 1.706144 >= 0.008500
#
#
# iteration:287
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 1.705148 >= 0.008500
#
#
# iteration:288
# iteration done! step: 228 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.704706 >= 0.008500
#
#
# iteration:289
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 1.700877 >= 0.008500
#
#
# iteration:290
# iteration done! step: 252 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.699650 >= 0.008500
#
#
# iteration:291
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 1.698207 >= 0.008500
#
#
# iteration:292
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 1.697573 >= 0.008500
#
#
# iteration:293
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.693205 >= 0.008500
#
#
# iteration:294
# iteration done! step: 230 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.690482 >= 0.008500
#
#
# iteration:295
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 1.688860 >= 0.008500
#
#
# iteration:296
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 1.687106 >= 0.008500
#
#
# iteration:297
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 1.683872 >= 0.008500
#
#
# iteration:298
# iteration done! step: 60 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.683341 >= 0.008500
#
#
# iteration:299
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 1.682906 >= 0.008500
#
#
# iteration:300
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 1.680048 >= 0.008500
#
#
# iteration:301
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 1.675226 >= 0.008500
#
#
# iteration:302
# iteration done! step: 299 reward: 0, state: 0 4
# action set[0, 1, 2, 3]
# 1.667888 >= 0.008500
#
#
# iteration:303
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 1.667712 >= 0.008500
#
#
# iteration:304
# iteration done! step: 104 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.666512 >= 0.008500
#
#
# iteration:305
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.665918 >= 0.008500
#
#
# iteration:306
# iteration done! step: 272 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.664868 >= 0.008500
#
#
# iteration:307
# iteration done! step: 299 reward: 0, state: 2 3
# action set[0, 1, 2, 3]
# 1.661709 >= 0.008500
#
#
# iteration:308
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 1.659858 >= 0.008500
#
#
# iteration:309
# iteration done! step: 299 reward: 0, state: 1 3
# action set[0, 1, 2, 3]
# 1.656482 >= 0.008500
#
#
# iteration:310
# iteration done! step: 168 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.656233 >= 0.008500
#
#
# iteration:311
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 1.653308 >= 0.008500
#
#
# iteration:312
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 1.650437 >= 0.008500
#
#
# iteration:313
# iteration done! step: 242 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.648147 >= 0.008500
#
#
# iteration:314
# iteration done! step: 299 reward: 0, state: 2 2
# action set[0, 1, 2, 3]
# 1.646862 >= 0.008500
#
#
# iteration:315
# iteration done! step: 299 reward: 0, state: 2 1
# action set[0, 1, 2, 3]
# 1.645557 >= 0.008500
#
#
# iteration:316
# iteration done! step: 299 reward: 0, state: 0 4
# action set[0, 1, 2, 3]
# 1.645288 >= 0.008500
#
#
# iteration:317
# iteration done! step: 256 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.645288 >= 0.008500
#
#
# iteration:318
# iteration done! step: 299 reward: 0, state: 3 3
# action set[0, 1, 2, 3]
# 1.643479 >= 0.008500
#
#
# iteration:319
# iteration done! step: 159 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.643165 >= 0.008500
#
#
# iteration:320
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 1.641616 >= 0.008500
#
#
# iteration:321
# iteration done! step: 299 reward: 0, state: 0 0
# action set[0, 1, 2, 3]
# 1.638635 >= 0.008500
#
#
# iteration:322
# iteration done! step: 122 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.636848 >= 0.008500
#
#
# iteration:323
# iteration done! step: 203 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.634796 >= 0.008500
#
#
# iteration:324
# iteration done! step: 174 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.634008 >= 0.008500
#
#
# iteration:325
# iteration done! step: 65 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.633529 >= 0.008500
#
#
# iteration:326
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 1.632621 >= 0.008500
#
#
# iteration:327
# iteration done! step: 211 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.632128 >= 0.008500
#
#
# iteration:328
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.631073 >= 0.008500
# iteration:329
# iteration done! step: 299 reward: 0, state: 2 0
# action set[0, 1, 2, 3]
# 1.629677 >= 0.008500
#
#
# iteration:330
# iteration done! step: 299 reward: 0, state: 0 2
# action set[0, 1, 2, 3]
# 1.628485 >= 0.008500
#
#
# iteration:331
# iteration done! step: 299 reward: 0, state: 1 4
# action set[0, 1, 2, 3]
# 1.627552 >= 0.008500
#
#
# iteration:332
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 1.625612 >= 0.008500
#
#
# iteration:333
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 1.621611 >= 0.008500
#
#
# iteration:334
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 1.617242 >= 0.008500
#
#
# iteration:335
# iteration done! step: 153 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.617242 >= 0.008500
#
#
# iteration:336
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 1.615711 >= 0.008500
#
#
# iteration:337
# iteration done! step: 252 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.614612 >= 0.008500
#
#
# iteration:338
# iteration done! step: 158 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.613827 >= 0.008500
#
#
# iteration:339
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 1.613164 >= 0.008500
#
#
# iteration:340
# iteration done! step: 191 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.612960 >= 0.008500
#
#
# iteration:341
# iteration done! step: 299 reward: 0, state: 2 4
# action set[0, 1, 2, 3]
# 1.610274 >= 0.008500
#
#
# iteration:342
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 1.609067 >= 0.008500
#
#
# iteration:343
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 1.605660 >= 0.008500
#
#
# iteration:344
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 1.602178 >= 0.008500
#
#
# iteration:345
# iteration done! step: 299 reward: 0, state: 1 4
# action set[0, 1, 2, 3]
# 1.597578 >= 0.008500
#
#
# iteration:346
# iteration done! step: 208 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.597278 >= 0.008500
#
#
# iteration:347
# iteration done! step: 299 reward: 0, state: 3 1
# action set[0, 1, 2, 3]
# 1.597129 >= 0.008500
#
#
# iteration:348
# iteration done! step: 299 reward: 0, state: 3 0
# action set[0, 1, 2, 3]
# 1.595576 >= 0.008500
#
#
# iteration:349
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 1.593307 >= 0.008500
#
#
# iteration:350
# iteration done! step: 299 reward: 0, state: 0 1
# action set[0, 1, 2, 3]
# 1.592176 >= 0.008500
#
#
# iteration:351
# iteration done! step: 205 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.591139 >= 0.008500
#
#
# iteration:352
# iteration done! step: 299 reward: 0, state: 1 0
# action set[0, 1, 2, 3]
# 1.587622 >= 0.008500
#
#
# iteration:353
# iteration done! step: 150 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.587622 >= 0.008500
#
#
# iteration:354
# iteration done! step: 299 reward: 0, state: 1 4
# action set[0, 1, 2, 3]
# 1.587267 >= 0.008500
#
#
# iteration:355
# iteration done! step: 299 reward: 0, state: 1 1
# action set[0, 1, 2, 3]
# 1.586695 >= 0.008500
#
#
# iteration:356
# iteration done! step: 287 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.583488 >= 0.008500
#
#
# iteration:357
# iteration done! step: 160 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.582019 >= 0.008500
#
#
# iteration:358
# iteration done! step: 299 reward: 0, state: 1 2
# action set[0, 1, 2, 3]
# 1.580006 >= 0.008500
#
#
# iteration:359
# iteration done! step: 199 reward: 1, state: 4 4
# action set[0, 1, 2, 3]
# 1.578997 >= 0.008500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-1b82a57ca6b1> in <module>
#       1 agent = Agent()
# ----> 2 agent.model_free_action_elimination()
#
# <ipython-input-54-c1ae253d29ae> in model_free_action_elimination(self)
#      47
#      48                 a = random.sample(self.U[s1][s2], 1)[0]
# ---> 49                 s1_next, s2_next, r, done, _ = self.step(a)
#      50
#      51                 # count(选中次数)
#
# <ipython-input-54-c1ae253d29ae> in step(self, a)
#      74
#      75     def step(self, a):
# ---> 76         s, r, done, _ = self.env.step(a)
#      77         # 将奖励大于0
#      78         r = max(r, 0.)
#
# ~/anaconda3/lib/python3.7/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      14     def step(self, action):
#      15         assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16         observation, reward, done, info = self.env.step(action)
#      17         self._elapsed_steps += 1
#      18         if self._elapsed_steps >= self._max_episode_steps:
#
# ~/anaconda3/lib/python3.7/site-packages/gym_maze/envs/maze_env.py in step(self, action)
#      65         """
#      66         if isinstance(action, int):
# ---> 67             self.maze_view.move_robot(self.actions[action])
#      68         elif isinstance(action, str):
#      69             self.maze_view.move_robot(action)
#
# ~/anaconda3/lib/python3.7/site-packages/gym_maze/envs/maze_view_2d.py in move_robot(self, direction)
#     208
#     209         if not current_cell.walls[direction]:
# --> 210             self.__color_robot(transparency=0)
#     211             self.__robot = self.robot + Maze.compass[direction]
#     212
#
# ~/anaconda3/lib/python3.7/site-packages/gym_maze/envs/maze_view_2d.py in __color_robot(self, color, transparency)
#     167         r0: int = min(self.cell_width, self.cell_height) // 5
#     168
# --> 169         pygame.draw.circle(self.__game_surface, color + (transparency,), (x0, y0), r0)
#     170
#     171     @staticmethod
#
# KeyboardInterrupt:

# %%
Q_upper = agent.Q_up
Q_lower = agent.Q_down
solution_policy = agent.solution_policy(Q_upper)
# Out:
# Return of solution =  0.0390269831338038

# %%
agent.animation(solution_policy, 50)
