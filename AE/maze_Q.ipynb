# %%
import numpy as np
import gym_maze
import gym
from gym import wrappers
import time

class Agent(object):
    def __init__(self):
        self.iter_max = 10000

        self.initial_lr = 1.0 # Learning rate
        self.min_lr = 0.003
        self.discount_rate = .83
        self.t_max = 100 # limit step in an episode
        self.eps = 0.1


        self.env = gym.make('maze-sample-5x5-v0')

        self.n_states = 5
        self.n_actions = self.env.action_space.n

        self.q_table = np.zeros((self.n_states, self.n_states, 4))
    
    def run_episode(self, policy=None, render=False):
        obs = self.env.reset()
        total_reward = 0
        step_idx = 0
        for _ in range(self.t_max):
            if render:
                self.env.render()
            if policy is None:
                action = self.env.action_space.sample()
            else:
                a,b = self.obs_to_state(obs)
                action = policy[a][b]
                action = int(action)
            obs, reward, done, _ = self.env.step(action)
            total_reward += self.discount_rate ** step_idx * reward
            step_idx += 1
            if done:
                break
        return total_reward

    def obs_to_state(self, obs):
        """ Maps an observation to state """
        # we quantify the continous state space into discrete space
        a = int(obs[0])
        b = int(obs[1])
        return a, b
    
    def update_q_table(self):
        for i in range(self.iter_max):
            obs = self.env.reset()
            total_reward = 0
            ## eta: learning rate is decreased at each step
            eta = max(self.min_lr, self.initial_lr * (0.85 ** (i//100)))
            for j in range(self.t_max):
                a, b = self.obs_to_state(obs)
                if np.random.uniform(0, 1) < self.eps:
                    action = np.random.choice(self.env.action_space.n)
                else:
                    action = np.argmax(self.q_table[a][b])
                    action = int(action)
                obs, reward, done, _ = self.env.step(action)
                total_reward += reward
                # update q table
                a_, b_ = self.obs_to_state(obs)
                self.q_table[a][b][action] = self.q_table[a][b][action] + eta * (reward + self.discount_rate *  np.max(self.q_table[a_][b_]) - self.q_table[a][b][action])

                if done:
                    break
            if i % 20 == 0:
                print('Iteration #%d -- Total reward = %f' %(i+1, total_reward))
        return self.q_table
    
    def solution_policy(self,table):
        policy = np.argmax(table, axis=2)
        policy_scores = [self.run_episode(policy, False) for _ in range(10)]
        print("Average score of solution = ", np.mean(policy_scores))
        return policy
        
    def animation(self, policy, count):
        for _ in range(count):
            self.run_episode(policy, True)
        self.env.close()

# %%
def main():
    agent = Agent()
    q_table = agent.update_q_table()
    policy = agent.solution_policy(q_table)
    agent.animation(policy,10)

if __name__ == '__main__':
    main()
# Out:
# Iteration #1 -- Total reward = -0.400000
# Iteration #21 -- Total reward = 0.932000
# Iteration #41 -- Total reward = 0.932000
# Iteration #61 -- Total reward = 0.928000
# Iteration #81 -- Total reward = 0.932000
# Iteration #101 -- Total reward = 0.928000
# Iteration #121 -- Total reward = 0.936000
# Iteration #141 -- Total reward = 0.920000
# Iteration #161 -- Total reward = 0.936000
# Iteration #181 -- Total reward = 0.928000
# Iteration #201 -- Total reward = 0.940000
# Iteration #221 -- Total reward = 0.940000
# Iteration #241 -- Total reward = 0.940000
# Iteration #261 -- Total reward = 0.924000
# Iteration #281 -- Total reward = 0.928000
# Iteration #301 -- Total reward = 0.936000
# Iteration #321 -- Total reward = 0.924000
# Iteration #341 -- Total reward = 0.928000
# Iteration #361 -- Total reward = 0.936000
# Iteration #381 -- Total reward = 0.928000
# Iteration #401 -- Total reward = 0.924000
# Iteration #421 -- Total reward = 0.932000
# Iteration #441 -- Total reward = 0.924000
# Iteration #461 -- Total reward = 0.936000
# Iteration #481 -- Total reward = 0.936000
# Iteration #501 -- Total reward = 0.932000
# Iteration #521 -- Total reward = 0.936000
# Iteration #541 -- Total reward = 0.932000
# Iteration #561 -- Total reward = 0.928000
# Iteration #581 -- Total reward = 0.936000
# Iteration #601 -- Total reward = 0.936000
# Iteration #621 -- Total reward = 0.924000
# Iteration #641 -- Total reward = 0.936000
# Iteration #661 -- Total reward = 0.924000
# Iteration #681 -- Total reward = 0.928000
# Iteration #701 -- Total reward = 0.932000
# Iteration #721 -- Total reward = 0.936000
# Iteration #741 -- Total reward = 0.928000
# Iteration #761 -- Total reward = 0.936000
# Iteration #781 -- Total reward = 0.916000
# Iteration #801 -- Total reward = 0.936000
# Iteration #821 -- Total reward = 0.928000
# Iteration #841 -- Total reward = 0.936000
# Iteration #861 -- Total reward = 0.936000
# Iteration #881 -- Total reward = 0.940000
# Iteration #901 -- Total reward = 0.924000
# Iteration #921 -- Total reward = 0.912000
# Iteration #941 -- Total reward = 0.932000
# Iteration #961 -- Total reward = 0.932000
# Iteration #981 -- Total reward = 0.924000
# Iteration #1001 -- Total reward = 0.936000
# Iteration #1021 -- Total reward = 0.916000
# Iteration #1041 -- Total reward = 0.940000
# Iteration #1061 -- Total reward = 0.924000
# Iteration #1081 -- Total reward = 0.940000
# Iteration #1101 -- Total reward = 0.924000
# Iteration #1121 -- Total reward = 0.936000
# Iteration #1141 -- Total reward = 0.912000
# Iteration #1161 -- Total reward = 0.936000
# Iteration #1181 -- Total reward = 0.932000
# Iteration #1201 -- Total reward = 0.932000
# Iteration #1221 -- Total reward = 0.940000
# Iteration #1241 -- Total reward = 0.928000
# Iteration #1261 -- Total reward = 0.932000
# Iteration #1281 -- Total reward = 0.936000
# Iteration #1301 -- Total reward = 0.940000
# Iteration #1321 -- Total reward = 0.940000
# Iteration #1341 -- Total reward = 0.936000
# Iteration #1361 -- Total reward = 0.936000
# Iteration #1381 -- Total reward = 0.928000
# Iteration #1401 -- Total reward = 0.940000
# Iteration #1421 -- Total reward = 0.940000
# Iteration #1441 -- Total reward = 0.932000
# Iteration #1461 -- Total reward = 0.940000
# Iteration #1481 -- Total reward = 0.940000
# Iteration #1501 -- Total reward = 0.928000
# Iteration #1521 -- Total reward = 0.920000
# Iteration #1541 -- Total reward = 0.936000
# Iteration #1561 -- Total reward = 0.936000
# Iteration #1581 -- Total reward = 0.936000
# Iteration #1601 -- Total reward = 0.936000
# Iteration #1621 -- Total reward = 0.936000
# Iteration #1641 -- Total reward = 0.932000
# Iteration #1661 -- Total reward = 0.932000
# Iteration #1681 -- Total reward = 0.924000
# Iteration #1701 -- Total reward = 0.928000
# Iteration #1721 -- Total reward = 0.936000
# Iteration #1741 -- Total reward = 0.940000
# Iteration #1761 -- Total reward = 0.936000
# Iteration #1781 -- Total reward = 0.936000
# Iteration #1801 -- Total reward = 0.928000
# Iteration #1821 -- Total reward = 0.932000
# Iteration #1841 -- Total reward = 0.932000
# Iteration #1861 -- Total reward = 0.936000
# Iteration #1881 -- Total reward = 0.928000
# Iteration #1901 -- Total reward = 0.936000
# Iteration #1921 -- Total reward = 0.924000
# Iteration #1941 -- Total reward = 0.924000
# Iteration #1961 -- Total reward = 0.940000
# Iteration #1981 -- Total reward = 0.932000
# Iteration #2001 -- Total reward = 0.928000
# Iteration #2021 -- Total reward = 0.936000
# Iteration #2041 -- Total reward = 0.932000
# Iteration #2061 -- Total reward = 0.928000
# Iteration #2081 -- Total reward = 0.940000
# Iteration #2101 -- Total reward = 0.936000
# Iteration #2121 -- Total reward = 0.940000
# Iteration #2141 -- Total reward = 0.932000
# Iteration #2161 -- Total reward = 0.928000
# Iteration #2181 -- Total reward = 0.924000
# Iteration #2201 -- Total reward = 0.940000
# Iteration #2221 -- Total reward = 0.928000
# Iteration #2241 -- Total reward = 0.936000
# Iteration #2261 -- Total reward = 0.936000
# Iteration #2281 -- Total reward = 0.936000
# Iteration #2301 -- Total reward = 0.912000
# Iteration #2321 -- Total reward = 0.924000
# Iteration #2341 -- Total reward = 0.936000
# Iteration #2361 -- Total reward = 0.932000
# Iteration #2381 -- Total reward = 0.928000
# Iteration #2401 -- Total reward = 0.940000
# Iteration #2421 -- Total reward = 0.936000
# Iteration #2441 -- Total reward = 0.928000
# Iteration #2461 -- Total reward = 0.940000
# Iteration #2481 -- Total reward = 0.928000
# Iteration #2501 -- Total reward = 0.932000
# Iteration #2521 -- Total reward = 0.928000
# Iteration #2541 -- Total reward = 0.936000
# Iteration #2561 -- Total reward = 0.936000
# Iteration #2581 -- Total reward = 0.932000
# Iteration #2601 -- Total reward = 0.936000
# Iteration #2621 -- Total reward = 0.940000
# Iteration #2641 -- Total reward = 0.940000
# Iteration #2661 -- Total reward = 0.940000
# Iteration #2681 -- Total reward = 0.940000
# Iteration #2701 -- Total reward = 0.932000
# Iteration #2721 -- Total reward = 0.928000
# Iteration #2741 -- Total reward = 0.936000
# Iteration #2761 -- Total reward = 0.936000
# Iteration #2781 -- Total reward = 0.932000
# Iteration #2801 -- Total reward = 0.936000
# Iteration #2821 -- Total reward = 0.940000
# Iteration #2841 -- Total reward = 0.940000
# Iteration #2861 -- Total reward = 0.924000
# Iteration #2881 -- Total reward = 0.940000
# Iteration #2901 -- Total reward = 0.936000
# Iteration #2921 -- Total reward = 0.936000
# Iteration #2941 -- Total reward = 0.936000
# Iteration #2961 -- Total reward = 0.928000
# Iteration #2981 -- Total reward = 0.936000
# Iteration #3001 -- Total reward = 0.928000
# Iteration #3021 -- Total reward = 0.936000
# Iteration #3041 -- Total reward = 0.940000
# Iteration #3061 -- Total reward = 0.940000
# Iteration #3081 -- Total reward = 0.932000
# Iteration #3101 -- Total reward = 0.916000
# Iteration #3121 -- Total reward = 0.932000
# Iteration #3141 -- Total reward = 0.940000
# Iteration #3161 -- Total reward = 0.940000
# Iteration #3181 -- Total reward = 0.936000
# Iteration #3201 -- Total reward = 0.936000
# Iteration #3221 -- Total reward = 0.940000
# Iteration #3241 -- Total reward = 0.940000
# Iteration #3261 -- Total reward = 0.940000
# Iteration #3281 -- Total reward = 0.932000
# Iteration #3301 -- Total reward = 0.932000
# Iteration #3321 -- Total reward = 0.928000
# Iteration #3341 -- Total reward = 0.928000
# Iteration #3361 -- Total reward = 0.924000
# Iteration #3381 -- Total reward = 0.936000
# Iteration #3401 -- Total reward = 0.924000
# Iteration #3421 -- Total reward = 0.940000
# Iteration #3441 -- Total reward = 0.940000
# Iteration #3461 -- Total reward = 0.936000
# Iteration #3481 -- Total reward = 0.928000
# Iteration #3501 -- Total reward = 0.924000
# Iteration #3521 -- Total reward = 0.932000
# Iteration #3541 -- Total reward = 0.940000
# Iteration #3561 -- Total reward = 0.932000
# Iteration #3581 -- Total reward = 0.940000
# Iteration #3601 -- Total reward = 0.936000
# Iteration #3621 -- Total reward = 0.940000
# Iteration #3641 -- Total reward = 0.924000
# Iteration #3661 -- Total reward = 0.936000
# Iteration #3681 -- Total reward = 0.936000
# Iteration #3701 -- Total reward = 0.936000
# Iteration #3721 -- Total reward = 0.928000
# Iteration #3741 -- Total reward = 0.928000
# Iteration #3761 -- Total reward = 0.924000
# Iteration #3781 -- Total reward = 0.916000
# Iteration #3801 -- Total reward = 0.920000
# Iteration #3821 -- Total reward = 0.936000
# Iteration #3841 -- Total reward = 0.936000
# Iteration #3861 -- Total reward = 0.940000
# Iteration #3881 -- Total reward = 0.932000
# Iteration #3901 -- Total reward = 0.936000
# Iteration #3921 -- Total reward = 0.936000
# Iteration #3941 -- Total reward = 0.928000
# Iteration #3961 -- Total reward = 0.932000
# Iteration #3981 -- Total reward = 0.940000
# Iteration #4001 -- Total reward = 0.932000
# Iteration #4021 -- Total reward = 0.924000
# Iteration #4041 -- Total reward = 0.932000
# Iteration #4061 -- Total reward = 0.940000
# Iteration #4081 -- Total reward = 0.928000
# Iteration #4101 -- Total reward = 0.932000
# Iteration #4121 -- Total reward = 0.932000
# Iteration #4141 -- Total reward = 0.936000
# Iteration #4161 -- Total reward = 0.940000
# Iteration #4181 -- Total reward = 0.940000
# Iteration #4201 -- Total reward = 0.936000
# Iteration #4221 -- Total reward = 0.924000
# Iteration #4241 -- Total reward = 0.940000
# Iteration #4261 -- Total reward = 0.940000
# Iteration #4281 -- Total reward = 0.928000
# Iteration #4301 -- Total reward = 0.936000
# Iteration #4321 -- Total reward = 0.940000
# Iteration #4341 -- Total reward = 0.924000
# Iteration #4361 -- Total reward = 0.936000
# Iteration #4381 -- Total reward = 0.928000
# Iteration #4401 -- Total reward = 0.936000
# Iteration #4421 -- Total reward = 0.936000
# Iteration #4441 -- Total reward = 0.940000
# Iteration #4461 -- Total reward = 0.936000
# Iteration #4481 -- Total reward = 0.940000
# Iteration #4501 -- Total reward = 0.932000
# Iteration #4521 -- Total reward = 0.928000
# Iteration #4541 -- Total reward = 0.928000
# Iteration #4561 -- Total reward = 0.936000
# Iteration #4581 -- Total reward = 0.924000
# Iteration #4601 -- Total reward = 0.940000
# Iteration #4621 -- Total reward = 0.936000
# Iteration #4641 -- Total reward = 0.928000
# Iteration #4661 -- Total reward = 0.928000
# Iteration #4681 -- Total reward = 0.936000
# Iteration #4701 -- Total reward = 0.932000
# Iteration #4721 -- Total reward = 0.936000
# Iteration #4741 -- Total reward = 0.936000
# Iteration #4761 -- Total reward = 0.936000
# Iteration #4781 -- Total reward = 0.916000
# Iteration #4801 -- Total reward = 0.936000
# Iteration #4821 -- Total reward = 0.936000
# Iteration #4841 -- Total reward = 0.924000
# Iteration #4861 -- Total reward = 0.940000
# Iteration #4881 -- Total reward = 0.936000
# Iteration #4901 -- Total reward = 0.932000
# Iteration #4921 -- Total reward = 0.940000
# Iteration #4941 -- Total reward = 0.940000
# Iteration #4961 -- Total reward = 0.936000
# Iteration #4981 -- Total reward = 0.936000
# Iteration #5001 -- Total reward = 0.940000
# Iteration #5021 -- Total reward = 0.920000
# Iteration #5041 -- Total reward = 0.936000
# Iteration #5061 -- Total reward = 0.940000
# Iteration #5081 -- Total reward = 0.932000
# Iteration #5101 -- Total reward = 0.932000
# Iteration #5121 -- Total reward = 0.924000
# Iteration #5141 -- Total reward = 0.932000
# Iteration #5161 -- Total reward = 0.936000
# Iteration #5181 -- Total reward = 0.936000
# Iteration #5201 -- Total reward = 0.936000
# Iteration #5221 -- Total reward = 0.936000
# Iteration #5241 -- Total reward = 0.932000
# Iteration #5261 -- Total reward = 0.940000
# Iteration #5281 -- Total reward = 0.920000
# Iteration #5301 -- Total reward = 0.924000
# Iteration #5321 -- Total reward = 0.940000
# Iteration #5341 -- Total reward = 0.936000
# Iteration #5361 -- Total reward = 0.936000
# Iteration #5381 -- Total reward = 0.936000
# Iteration #5401 -- Total reward = 0.940000
# Iteration #5421 -- Total reward = 0.932000
# Iteration #5441 -- Total reward = 0.936000
# Iteration #5461 -- Total reward = 0.932000
# Iteration #5481 -- Total reward = 0.940000
# Iteration #5501 -- Total reward = 0.940000
# Iteration #5521 -- Total reward = 0.940000
# Iteration #5541 -- Total reward = 0.940000
# Iteration #5561 -- Total reward = 0.936000
# Iteration #5581 -- Total reward = 0.940000
# Iteration #5601 -- Total reward = 0.928000
# Iteration #5621 -- Total reward = 0.936000
# Iteration #5641 -- Total reward = 0.916000
# Iteration #5661 -- Total reward = 0.928000
# Iteration #5681 -- Total reward = 0.936000
# Iteration #5701 -- Total reward = 0.928000
# Iteration #5721 -- Total reward = 0.932000
# Iteration #5741 -- Total reward = 0.940000
# Iteration #5761 -- Total reward = 0.940000
# Iteration #5781 -- Total reward = 0.940000
# Iteration #5801 -- Total reward = 0.924000
# Iteration #5821 -- Total reward = 0.940000
# Iteration #5841 -- Total reward = 0.940000
# Iteration #5861 -- Total reward = 0.932000
# Iteration #5881 -- Total reward = 0.940000
# Iteration #5901 -- Total reward = 0.940000
# Iteration #5921 -- Total reward = 0.932000
# Iteration #5941 -- Total reward = 0.940000
# Iteration #5961 -- Total reward = 0.928000
# Iteration #5981 -- Total reward = 0.928000
# Iteration #6001 -- Total reward = 0.924000
# Iteration #6021 -- Total reward = 0.928000
# Iteration #6041 -- Total reward = 0.940000
# Iteration #6061 -- Total reward = 0.936000
# Iteration #6081 -- Total reward = 0.936000
# Iteration #6101 -- Total reward = 0.940000
# Iteration #6121 -- Total reward = 0.936000
# Iteration #6141 -- Total reward = 0.920000
# Iteration #6161 -- Total reward = 0.920000
# Iteration #6181 -- Total reward = 0.936000
# Iteration #6201 -- Total reward = 0.940000
# Iteration #6221 -- Total reward = 0.932000
# Iteration #6241 -- Total reward = 0.932000
# Iteration #6261 -- Total reward = 0.912000
# Iteration #6281 -- Total reward = 0.936000
# Iteration #6301 -- Total reward = 0.936000
# Iteration #6321 -- Total reward = 0.932000
# Iteration #6341 -- Total reward = 0.940000
# Iteration #6361 -- Total reward = 0.940000
# Iteration #6381 -- Total reward = 0.932000
# Iteration #6401 -- Total reward = 0.928000
# Iteration #6421 -- Total reward = 0.936000
# Iteration #6441 -- Total reward = 0.940000
# Iteration #6461 -- Total reward = 0.928000
# Iteration #6481 -- Total reward = 0.940000
# Iteration #6501 -- Total reward = 0.936000
# Iteration #6521 -- Total reward = 0.936000
# Iteration #6541 -- Total reward = 0.940000
# Iteration #6561 -- Total reward = 0.932000
# Iteration #6581 -- Total reward = 0.940000
# Iteration #6601 -- Total reward = 0.932000
# Iteration #6621 -- Total reward = 0.928000
# Iteration #6641 -- Total reward = 0.940000
# Iteration #6661 -- Total reward = 0.936000
# Iteration #6681 -- Total reward = 0.936000
# Iteration #6701 -- Total reward = 0.940000
# Iteration #6721 -- Total reward = 0.932000
# Iteration #6741 -- Total reward = 0.936000
# Iteration #6761 -- Total reward = 0.932000
# Iteration #6781 -- Total reward = 0.916000
# Iteration #6801 -- Total reward = 0.940000
# Iteration #6821 -- Total reward = 0.936000
# Iteration #6841 -- Total reward = 0.932000
# Iteration #6861 -- Total reward = 0.932000
# Iteration #6881 -- Total reward = 0.928000
# Iteration #6901 -- Total reward = 0.932000
# Iteration #6921 -- Total reward = 0.920000
# Iteration #6941 -- Total reward = 0.936000
# Iteration #6961 -- Total reward = 0.940000
# Iteration #6981 -- Total reward = 0.924000
# Iteration #7001 -- Total reward = 0.928000
# Iteration #7021 -- Total reward = 0.928000
# Iteration #7041 -- Total reward = 0.928000
# Iteration #7061 -- Total reward = 0.940000
# Iteration #7081 -- Total reward = 0.940000
# Iteration #7101 -- Total reward = 0.900000
# Iteration #7121 -- Total reward = 0.920000
# Iteration #7141 -- Total reward = 0.928000
# Iteration #7161 -- Total reward = 0.940000
# Iteration #7181 -- Total reward = 0.936000
# Iteration #7201 -- Total reward = 0.940000
# Iteration #7221 -- Total reward = 0.932000
# Iteration #7241 -- Total reward = 0.932000
# Iteration #7261 -- Total reward = 0.936000
# Iteration #7281 -- Total reward = 0.924000
# Iteration #7301 -- Total reward = 0.928000
# Iteration #7321 -- Total reward = 0.928000
# Iteration #7341 -- Total reward = 0.940000
# Iteration #7361 -- Total reward = 0.932000
# Iteration #7381 -- Total reward = 0.936000
# Iteration #7401 -- Total reward = 0.940000
# Iteration #7421 -- Total reward = 0.936000
# Iteration #7441 -- Total reward = 0.932000
# Iteration #7461 -- Total reward = 0.920000
# Iteration #7481 -- Total reward = 0.932000
# Iteration #7501 -- Total reward = 0.928000
# Iteration #7521 -- Total reward = 0.940000
# Iteration #7541 -- Total reward = 0.932000
# Iteration #7561 -- Total reward = 0.936000
# Iteration #7581 -- Total reward = 0.928000
# Iteration #7601 -- Total reward = 0.928000
# Iteration #7621 -- Total reward = 0.932000
# Iteration #7641 -- Total reward = 0.928000
# Iteration #7661 -- Total reward = 0.900000
# Iteration #7681 -- Total reward = 0.924000
# Iteration #7701 -- Total reward = 0.908000
# Iteration #7721 -- Total reward = 0.940000
# Iteration #7741 -- Total reward = 0.928000
# Iteration #7761 -- Total reward = 0.940000
# Iteration #7781 -- Total reward = 0.936000
# Iteration #7801 -- Total reward = 0.932000
# Iteration #7821 -- Total reward = 0.932000
# Iteration #7841 -- Total reward = 0.928000
# Iteration #7861 -- Total reward = 0.936000
# Iteration #7881 -- Total reward = 0.928000
# Iteration #7901 -- Total reward = 0.940000
# Iteration #7921 -- Total reward = 0.940000
# Iteration #7941 -- Total reward = 0.940000
# Iteration #7961 -- Total reward = 0.940000
# Iteration #7981 -- Total reward = 0.936000
# Iteration #8001 -- Total reward = 0.940000
# Iteration #8021 -- Total reward = 0.928000
# Iteration #8041 -- Total reward = 0.936000
# Iteration #8061 -- Total reward = 0.940000
# Iteration #8081 -- Total reward = 0.908000
# Iteration #8101 -- Total reward = 0.940000
# Iteration #8121 -- Total reward = 0.932000
# Iteration #8141 -- Total reward = 0.928000
# Iteration #8161 -- Total reward = 0.940000
# Iteration #8181 -- Total reward = 0.936000
# Iteration #8201 -- Total reward = 0.932000
# Iteration #8221 -- Total reward = 0.928000
# Iteration #8241 -- Total reward = 0.940000
# Iteration #8261 -- Total reward = 0.936000
# Iteration #8281 -- Total reward = 0.940000
# Iteration #8301 -- Total reward = 0.936000
# Iteration #8321 -- Total reward = 0.916000
# Iteration #8341 -- Total reward = 0.924000
# Iteration #8361 -- Total reward = 0.940000
# Iteration #8381 -- Total reward = 0.940000
# Iteration #8401 -- Total reward = 0.932000
# Iteration #8421 -- Total reward = 0.928000
# Iteration #8441 -- Total reward = 0.924000
# Iteration #8461 -- Total reward = 0.924000
# Iteration #8481 -- Total reward = 0.936000
# Iteration #8501 -- Total reward = 0.936000
# Iteration #8521 -- Total reward = 0.940000
# Iteration #8541 -- Total reward = 0.928000
# Iteration #8561 -- Total reward = 0.936000
# Iteration #8581 -- Total reward = 0.940000
# Iteration #8601 -- Total reward = 0.932000
# Iteration #8621 -- Total reward = 0.936000
# Iteration #8641 -- Total reward = 0.928000
# Iteration #8661 -- Total reward = 0.940000
# Iteration #8681 -- Total reward = 0.936000
# Iteration #8701 -- Total reward = 0.932000
# Iteration #8721 -- Total reward = 0.924000
# Iteration #8741 -- Total reward = 0.932000
# Iteration #8761 -- Total reward = 0.940000
# Iteration #8781 -- Total reward = 0.928000
# Iteration #8801 -- Total reward = 0.940000
# Iteration #8821 -- Total reward = 0.924000
# Iteration #8841 -- Total reward = 0.936000
# Iteration #8861 -- Total reward = 0.920000
# Iteration #8881 -- Total reward = 0.920000
# Iteration #8901 -- Total reward = 0.932000
# Iteration #8921 -- Total reward = 0.936000
# Iteration #8941 -- Total reward = 0.940000
# Iteration #8961 -- Total reward = 0.928000
# Iteration #8981 -- Total reward = 0.936000
# Iteration #9001 -- Total reward = 0.932000
# Iteration #9021 -- Total reward = 0.936000
# Iteration #9041 -- Total reward = 0.928000
# Iteration #9061 -- Total reward = 0.924000
# Iteration #9081 -- Total reward = 0.936000
# Iteration #9101 -- Total reward = 0.940000
# Iteration #9121 -- Total reward = 0.924000
# Iteration #9141 -- Total reward = 0.940000
# Iteration #9161 -- Total reward = 0.932000
# Iteration #9181 -- Total reward = 0.936000
# Iteration #9201 -- Total reward = 0.932000
# Iteration #9221 -- Total reward = 0.924000
# Iteration #9241 -- Total reward = 0.940000
# Iteration #9261 -- Total reward = 0.936000
# Iteration #9281 -- Total reward = 0.912000
# Iteration #9301 -- Total reward = 0.924000
# Iteration #9321 -- Total reward = 0.932000
# Iteration #9341 -- Total reward = 0.932000
# Iteration #9361 -- Total reward = 0.936000
# Iteration #9381 -- Total reward = 0.928000
# Iteration #9401 -- Total reward = 0.936000
# Iteration #9421 -- Total reward = 0.928000
# Iteration #9441 -- Total reward = 0.940000
# Iteration #9461 -- Total reward = 0.928000
# Iteration #9481 -- Total reward = 0.940000
# Iteration #9501 -- Total reward = 0.924000
# Iteration #9521 -- Total reward = 0.928000
# Iteration #9541 -- Total reward = 0.928000
# Iteration #9561 -- Total reward = 0.936000
# Iteration #9581 -- Total reward = 0.920000
# Iteration #9601 -- Total reward = 0.936000
# Iteration #9621 -- Total reward = 0.928000
# Iteration #9641 -- Total reward = 0.940000
# Iteration #9661 -- Total reward = 0.920000
# Iteration #9681 -- Total reward = 0.928000
# Iteration #9701 -- Total reward = 0.940000
# Iteration #9721 -- Total reward = 0.936000
# Iteration #9741 -- Total reward = 0.932000
# Iteration #9761 -- Total reward = 0.932000
# Iteration #9781 -- Total reward = 0.936000
# Iteration #9801 -- Total reward = 0.908000
# Iteration #9821 -- Total reward = 0.932000
# Iteration #9841 -- Total reward = 0.928000
# Iteration #9861 -- Total reward = 0.936000
# Iteration #9881 -- Total reward = 0.936000
# Iteration #9901 -- Total reward = 0.932000
# Iteration #9921 -- Total reward = 0.940000
# Iteration #9941 -- Total reward = 0.928000
# Iteration #9961 -- Total reward = 0.936000
# Iteration #9981 -- Total reward = 0.928000
# Average score of solution =  0.0390269831338038
